# %%
#Analytics libraries
import numpy as np
import pandas as pd

#API libraries
import requests
import json

# %%
url= 'https://statistics.kilimo.go.ke/en/api/apputils/'

response=requests.get(url)
data=response.json()

# %%
print(json.dumps(data, indent=4))
# Out:
# {
#     "county": [
#         {
#             "id": 35,
#             "name": "Baringo",
#             "code": "30"
#         },
#         {
#             "id": 2,
#             "name": "Bomet",
#             "code": "36"
#         },
#         {
#             "id": 3,
#             "name": "Bungoma",
#             "code": "39"
#         },
#         {
#             "id": 4,
#             "name": "Busia",
#             "code": "40"
#         },
#         {
#             "id": 5,
#             "name": "Elgeyo Marakwet",
#             "code": "28"
#         },
#         {
#             "id": 6,
#             "name": "Embu",
#             "code": "14"
#         },
#         {
#             "id": 7,
#             "name": "Garrisa",
#             "code": "7"
#         },
#         {
#             "id": 8,
#             "name": "Homabay",
#             "code": "43"
#         },
#         {
#             "id": 19,
#             "name": "Isiolo",
#             "code": "11"
#         },
# ...

# %%
df = pd.json_normalize(data)

# %%
df.head()
# Out:
#                                               county  \
# 0  [{'id': 35, 'name': 'Baringo', 'code': '30'}, ...
#
#                                            subsector  \
# 0  [{'id': 1, 'name': 'Crops', 'codingsystem': 'A...
#
#                                               domain  \
# 0  [{'id': 1, 'name': 'CropsProductivity', 'displ...
#
#                                        domainelement  \
# 0  [{'id': 94, 'name': 'AnnualInflation', 'displa...
#
#                                          elementitem  \
# 0  [{'id': 62, 'name': 'Average Monthly Prices', ...
#
#                                       items_category  \
# 0  [{'id': 5, 'name': 'Crops', 'description': ''}...
#
#                                                  uom  \
# 0  [{'id': 14, 'name': 'Acres'}, {'id': 13, 'name...
#
#                                        items_specify
# 0  [{'id': 811, 'name': 'MaizeSeedQuantityofSeeds...

# %%
 df2=pd.json_normalize(df['county'])

# %%
df2.head()
# Out:
#                                             0   \
# 0  {'id': 35, 'name': 'Baringo', 'code': '30'}
#
#                                          1   \
# 0  {'id': 2, 'name': 'Bomet', 'code': '36'}
#
#                                            2   \
# 0  {'id': 3, 'name': 'Bungoma', 'code': '39'}
#
#                                          3   \
# 0  {'id': 4, 'name': 'Busia', 'code': '40'}
#
#                                                   4   \
# 0  {'id': 5, 'name': 'Elgeyo Marakwet', 'code': '...
#
#                                         5   \
# 0  {'id': 6, 'name': 'Embu', 'code': '14'}
#
#                                           6   \
# 0  {'id': 7, 'name': 'Garrisa', 'code': '7'}
#
#                                            7   \
# 0  {'id': 8, 'name': 'Homabay', 'code': '43'}
#
#                                            8   \
# 0  {'id': 19, 'name': 'Isiolo', 'code': '11'}
#
#                                             9   ...  \
# ...

# %%
 df3=pd.json_normalize(df2[0])

# %%
df3.head()
# Out:
#    id     name code
# 0  35  Baringo   30
